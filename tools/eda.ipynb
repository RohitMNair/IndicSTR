# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
# Character frequencies
char_frequencies = {
    'क': 2373631, 'ख': 353145, 'ग': 1135287, 'घ': 101759, 'ङ': 12668, 'च': 587083, 'छ': 126648, 'ज': 1066324,
    'झ': 79937, 'ञ': 36044, 'ट': 922799, 'ठ': 109926, 'ड': 745935, 'ढ': 89576, 'ण': 295839, 'त': 1913863,
    'थ': 269905, 'द': 1187796, 'ध': 388371, 'न': 2469234, 'प': 1506913, 'फ': 360268, 'ब': 1034525, 'भ': 382444,
    'म': 1897816, 'य': 1520446, 'र': 3891198, 'ल': 1885805, 'ळ': 9917, 'व': 1476368, 'श': 687269, 'ष': 294021,
    'स': 2294384, 'ह': 1180299, 'अ': 476957, 'आ': 342743, 'इ': 305052, 'ई': 225797, 'उ': 208732, 'ऊ': 40700,
    'ऋ': 6622, 'ॠ': 557, 'ए': 433169, 'ऐ': 31181, 'ओ': 121164, 'औ': 38590, 'ॲ': 21, 'ऍ': 4055, 'ऑ': 19609,
    'ॐ': 1943, '₹': 16, '।': 298925, '!': 171217, '$': 3758, ',': 869962, '.': 2460083, '-': 1351903, '%': 31771,
    '॥': 25618, 'ॽ': 36, '०': 90341, '१': 85461, '२': 64568, '३': 42780, '४': 37278, '५': 39299, '६': 32817,
    '७': 32082, '८': 34446, '९': 39452, 'ा': 5172908, 'ि': 2543686, 'ी': 2048072, 'ु': 1156564, 'ू': 564402,
    'ृ': 111363, 'े': 2146783, 'ै': 464853, 'ो': 1467529, 'ौ': 151267, 'ॅ': 19254, 'ॉ': 140422, 'ँ': 170390,
    'ं': 1822496, 'ः': 53808, '़': 455889, '्': 3967570
}

# Group frequencies
group_frequencies = {
    3: 1141222, 4: 1671745, 6: 967937, 9: 203259, 5: 1453112, 2: 276835, 10: 113017, 8: 354577, 7: 606491, 11: 64597,
    12: 38899, 23: 1601, 13: 24969, 14: 17421, 18: 5020, 15: 12479, 1: 10042, 27: 704, 17: 6459, 16: 8525, 84: 25,
    21: 2502, 22: 1869, 19: 3808, 25: 997, 20: 3420, 48: 66, 35: 246, 49: 74, 26: 874, 24: 1200, 59: 46, 39: 106,
    78: 24, 37: 198, 36: 246, 29: 577, 44: 103, 61: 40, 72: 38, 28: 661, 60: 28, 50: 83, 32: 338, 55: 36, 64: 41,
    30: 488, 71: 47, 34: 296, 46: 98, 31: 389, 43: 151, 45: 75, 68: 32, 80: 14, 47: 101, 92: 12, 98: 13, 53: 45,
    52: 61, 58: 40, 69: 45, 33: 310, 41: 137, 40: 161, 94: 4, 90: 3, 51: 68, 75: 22, 63: 29, 85: 12, 62: 24, 88: 18,
    79: 22, 87: 10, 81: 20, 95: 5, 42: 126, 38: 151, 54: 46, 56: 38, 99: 9, 77: 27, 57: 45, 70: 34, 100: 1, 83: 14,
    67: 24, 66: 18, 86: 19, 65: 19, 74: 23, 91: 5, 82: 17, 76: 23, 73: 30, 96: 6, 93: 7, 97: 5, 89: 4
}

def plot_frequencies(title, frequencies):
    labels, values = zip(*sorted(frequencies.items()))
    
    font_prop = FontProperties(fname='/home/rohitn/D1/synthtiger/resources/Devanagari/NotoSans-Regular.ttf', size=18)
    plt.figure(figsize=(16, 8))
    plt.bar(labels, values)
    plt.xlabel('Characters' if title == 'Character' else 'Groups')
    plt.ylabel('Frequency')
    plt.title(f'{title} Frequency Plot')
    plt.xticks(labels,rotation=90)
    ax = plt.subplot()
    for label in (ax.get_xticklabels() + ax.get_yticklabels()):
        label.set_fontproperties(font_prop)
        label.set_fontsize(10)

    plt.tight_layout()
    plt.show()

# Plotting character frequencies
plot_frequencies('Character', char_frequencies)

# Plotting group frequencies
plot_frequencies('Group', group_frequencies)
